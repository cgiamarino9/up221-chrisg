# %% [markdown]
# # Week 2 assignment
# ## data exploration
# My name is Chris G and I'm exploring data.

# %%
# importing python libraries 
import pandas as pd
import geopandas as gpd

# %%
# read and add shapefile to notebook
metro = gpd.read_file('data/Metro_Stations.geojson')
metro
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /opt/conda/share/proj failed
#      OBJECTID                                       source ext_id  \
# 0       72713  Metropolitan Transportation Authority (MTA)   None
# 1       72714  Metropolitan Transportation Authority (MTA)   None
# 2       72715  Metropolitan Transportation Authority (MTA)   None
# 3       72716  Metropolitan Transportation Authority (MTA)   None
# 4       72717  Metropolitan Transportation Authority (MTA)   None
# ..        ...                                          ...    ...
# 125     72838  Metropolitan Transportation Authority (MTA)   None
# 126     72839  Metropolitan Transportation Authority (MTA)   None
# 127     72840  Metropolitan Transportation Authority (MTA)   None
# 128     72841  Metropolitan Transportation Authority (MTA)   None
# 129     72842  Metropolitan Transportation Authority (MTA)   None
#
#                cat1            cat2  cat3 org_name  \
# ...
